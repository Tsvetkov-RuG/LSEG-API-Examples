# %% [markdown]
# # Minimum Working Example
#
# This is an MWE to verify that the API connection works.

# %% [markdown]
# Import packages.
#
# _Note that first time you may need to restart your Jupyter IDE a couple of times to make it work!_
#
# Make sure that the path to the directory with lseg-data.config.json file is correct and the file contains the API key, username, and password.

# %%
import lseg.data as ld
import os

# os.environ["LD_LIB_CONFIG_PATH"] = "../Configuration"
os.environ["LD_LIB_CONFIG_PATH"] = "../../../rug/lseg/Configuration"
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x1d32aaf4980 {name='ldp'}>

# %% [markdown]
# Open the session

# %% [markdown]
# Run your code

# %%
df = ld.get_history(universe="LSEG.L")
print(df.head())
# Out:
# LSEG.L       TRDPRC_1  MKT_HIGH    MKT_LOW  ACVOL_UNS  MKT_OPEN   BID   ASK  \
# Date
# 2026-02-12     7500.0    7622.0     7408.0    2974351      7492  7518  7520
# 2026-02-13     7584.0    7732.0     7540.0    2536081      7630  7570  7572
# 2026-02-16     7610.0    7726.0  7596.3241     906082      7722  7610  7612
# 2026-02-17  7576.1579    7658.0     7510.0    1459808      7634  7572  7574
# 2026-02-18     7728.0    7808.0     7438.0    1896946      7500  7788  7790
#
# LSEG.L              TRNOVR_UNS    VWAP  MID_PRICE  ...  INT_AUC  INT_AUCVOL  \
# Date                                               ...
# 2026-02-12  22335833962.799999  7508.0       7519  ...     <NA>        <NA>
# 2026-02-13  19312571531.903461  7614.0       7571  ...     <NA>        <NA>
# 2026-02-16    6921787951.72249  7637.6       7611  ...     <NA>        <NA>
# 2026-02-17   11248345454.42207  7592.0       7573  ...     <NA>        <NA>
# 2026-02-18  14580711384.700001  7681.0       7789  ...     <NA>        <NA>
#
# LSEG.L      EX_VOL_UNS  ALL_C_MOVE  ELG_NUMMOV  NAVALUE    TURN_ORDB  \
# Date
# 2026-02-12     2975033       20264       13730     <NA>  13206915284
# 2026-02-13     2536239       13686        9372     <NA>   8542541304
# 2026-02-16      906267       11396        6423     <NA>   4887989847
# 2026-02-17     1481803      371843        7483     <NA>   6773947814
# 2026-02-18     1896975       15285       14077     <NA>  10170456940
#
# LSEG.L      ELG_ACVOL  ORDBK_TRD  OB_NUMMOV
# Date
# 2026-02-12    1810956       7520      13383
# 2026-02-13    1359357       7570       9039
# 2026-02-16     813995       7612       6164
# 2026-02-17     963468       7572       7255
# 2026-02-18    1433872       7790      13786
#
# [5 rows x 36 columns]
# C:\Users\Artem\workspace\github\LSEG-API-Examples\.venv\Lib\site-packages\lseg\data\_tools\_dataframe.py:177:FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %% [markdown]
# Close the session. If the previous session is not closed, close it here to avoid error messages.

# %%
ld.close_session()
